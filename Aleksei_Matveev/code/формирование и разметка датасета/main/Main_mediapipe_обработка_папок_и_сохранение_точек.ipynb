# %%
# !pip install mediapipe opencv-python-headless
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 26.8 MB/s eta 0:00:00
# ...

# %%
import gdown, os, shutil                                                        # Системные инструменты
from tqdm.auto import tqdm                                                      # Модуль для создания прогресс-бара при выполнении циклов
import csv
import mediapipe as mp                                                          # Библиотека MediaPipe
import cv2
import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('dataset.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow([ 'correct', 'main_folder', 'folder', 'filename', 'frame#', 'x_0', 'y_0', 'z_0', 'v_0',
                     'x_1', 'y_1', 'z_1', 'v_1', 'x_2', 'y_2', 'z_2', 'v_2',
                     'x_3', 'y_3', 'z_3', 'v_3', 'x_4', 'y_4', 'z_4', 'v_4',
                     'x_5', 'y_5', 'z_5', 'v_5', 'x_6', 'y_6', 'z_6', 'v_6',
                     'x_7', 'y_7', 'z_7', 'v_7', 'x_8', 'y_8', 'z_8', 'v_8',
                     'x_9', 'y_9', 'z_9', 'v_9', 'x_10', 'y_10', 'z_10', 'v_10',
                     'x_11', 'y_11', 'z_11', 'v_11', 'x_12', 'y_12', 'z_12', 'v_12',
                     'x_13', 'y_13', 'z_13', 'v_13', 'x_14', 'y_14', 'z_14', 'v_14',
                     'x_15', 'y_15', 'z_15', 'v_15', 'x_16', 'y_16', 'z_16', 'v_16',
                     'x_17', 'y_17', 'z_17', 'v_17', 'x_18', 'y_18', 'z_18', 'v_18',
                     'x_19', 'y_19', 'z_19', 'v_19', 'x_20', 'y_20', 'z_20', 'v_20',
                     'x_21', 'y_21', 'z_21', 'v_21', 'x_22', 'y_22', 'z_22', 'v_22',
                     'x_23', 'y_23', 'z_23', 'v_23', 'x_24', 'y_24', 'z_24', 'v_24',
                     'x_25', 'y_25', 'z_25', 'v_25', 'x_26', 'y_26', 'z_26', 'v_26',
                     'x_27', 'y_27', 'z_27', 'v_27', 'x_28', 'y_28', 'z_28', 'v_28',
                     'x_29', 'y_29', 'z_29', 'v_29', 'x_30', 'y_30', 'z_30', 'v_30',
                     'x_31', 'y_31', 'z_31', 'v_31', 'x_32', 'y_32', 'z_32', 'v_32',
                     'wx_0', 'wy_0', 'wz_0', 'wv_0',
                     'wx_1', 'wy_1', 'wz_1', 'wv_1', 'wx_2', 'wy_2', 'wz_2', 'wv_2',
                     'wx_3', 'wy_3', 'wz_3', 'wv_3', 'wx_4', 'wy_4', 'wz_4', 'wv_4',
                     'wx_5', 'wy_5', 'wz_5', 'wv_5', 'wx_6', 'wy_6', 'wz_6', 'wv_6',
                     'wx_7', 'wy_7', 'wz_7', 'wv_7', 'wx_8', 'wy_8', 'wz_8', 'wv_8',
                     'wx_9', 'wy_9', 'wz_9', 'wv_9', 'wx_10', 'wy_10', 'wz_10', 'wv_10',
                     'wx_11', 'wy_11', 'wz_11', 'wv_11', 'wx_12', 'wy_12', 'wz_12', 'wv_12',
                     'wx_13', 'wy_13', 'wz_13', 'wv_13', 'wx_14', 'wy_14', 'wz_14', 'wv_14',
                     'wx_15', 'wy_15', 'wz_15', 'wv_15', 'wx_16', 'wy_16', 'wz_16', 'wv_16',
                     'wx_17', 'wy_17', 'wz_17', 'wv_17', 'wx_18', 'wy_18', 'wz_18', 'wv_18',
                     'wx_19', 'wy_19', 'wz_19', 'wv_19', 'wx_20', 'wy_20', 'wz_20', 'wv_20',
                     'wx_21', 'wy_21', 'wz_21', 'wv_21', 'wx_22', 'wy_22', 'wz_22', 'wv_22',
                     'wx_23', 'wy_23', 'wz_23', 'wv_23', 'wx_24', 'wy_24', 'wz_24', 'wv_24',
                     'wx_25', 'wy_25', 'wz_25', 'wv_25', 'wx_26', 'wy_26', 'wz_26', 'wv_26',
                     'wx_27', 'wy_27', 'wz_27', 'wv_27', 'wx_28', 'wy_28', 'wz_28', 'wv_28',
                     'wx_29', 'wy_29', 'wz_29', 'wv_29', 'wx_30', 'wy_30', 'wz_30', 'wv_30',
                     'wx_31', 'wy_31', 'wz_31', 'wv_31', 'wx_32', 'wy_32', 'wz_32', 'wv_32'])

# %%
video_files = []
for root, dirs, files in os.walk('/content/drive/MyDrive/internship/karate/dataset'):
    for file in files:
      video_files.append(os.path.join(root, file))

# %%
video_files
# Out:
# ['/content/drive/MyDrive/internship/karate/dataset/dataset_part1.csv',
#  '/content/drive/MyDrive/internship/karate/dataset/dataset_part2.csv',
#  '/content/drive/MyDrive/internship/karate/dataset/dataset_part3.csv',
#  '/content/drive/MyDrive/internship/karate/dataset/dataset4.csv',
#  '/content/drive/MyDrive/internship/karate/dataset/wrong/УРАКЕН УЧИ (КРУГОВОЙ УДАР ПЕРЕДНЕЙ РУКОЙ)/side/Андрей УРАКЕН УЧИ (нет замаха 2).mp4',
#  '/content/drive/MyDrive/internship/karate/dataset/wrong/УРАКЕН УЧИ (КРУГОВОЙ УДАР ПЕРЕДНЕЙ РУКОЙ)/side/Андрей УРАКЕН УЧИ (положение кулака 2).mp4',
#  '/content/drive/MyDrive/internship/karate/dataset/wrong/УРАКЕН УЧИ (КРУГОВОЙ УДАР ПЕРЕДНЕЙ РУКОЙ)/side/Андрей УРАКЕН УЧИ (удар с сильным проносом 2).mp4',
#  '/content/drive/MyDrive/internship/karate/dataset/wrong/УРАКЕН УЧИ (КРУГОВОЙ УДАР ПЕРЕДНЕЙ РУКОЙ)/side/Максим УРАКЕН УЧИ (нет замаха 2).mp4',
# ...

# %%
#video_files=['/content/drive/MyDrive/internship/karate/dataset/wrong/УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)/side/Андрей УЧИ УКЕ (кулак развернут не верно 2).mp4',
 #'/content/drive/MyDrive/internship/karate/dataset/wrong/УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)/side/Максим УЧИ УКЕ (замах от плеча 2).mp4',
 #'/content/drive/MyDrive/internship/karate/dataset/wrong/УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)/side/Максим УЧИ УКЕ (корпус шомен 2).mp4',
 #'/content/drive/MyDrive/internship/karate/dataset/wrong/УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)/side/Максим УЧИ УКЕ (кулак развернут не верно 2).mp4']
#video_files
# Out:
# ['/content/drive/MyDrive/internship/karate/dataset/wrong/УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)/side/Андрей УЧИ УКЕ (кулак развернут не верно 2).mp4',
#  '/content/drive/MyDrive/internship/karate/dataset/wrong/УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)/side/Максим УЧИ УКЕ (замах от плеча 2).mp4',
#  '/content/drive/MyDrive/internship/karate/dataset/wrong/УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)/side/Максим УЧИ УКЕ (корпус шомен 2).mp4',
#  '/content/drive/MyDrive/internship/karate/dataset/wrong/УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)/side/Максим УЧИ УКЕ (кулак развернут не верно 2).mp4']

# %% [markdown]
# ## 4. Функция обрабатки видеофайла -> записывает скелетные точки в файл CSV.

# %%
mp_pose = mp.solutions.pose                                                     # Создаем объекты для обнаружения скелетных точек на изображении

def process_video(video_file,flip=False):                                                  # Функция которая принимает на вход путь к видео файлу
    folder = video_file.split(sep='/')[-4:]                                     # Разделяем путь к файлу на части: имя файла и имена папок
    print(folder)
    filename_no_ext = os.path.splitext(folder[3])[0]                            # Получаем имя файла без расширения, чтобы использовать его в качестве идентификатора
    if flip:
      filename_no_ext=filename_no_ext+'_flip'

    with mp_pose.Pose(model_complexity=2,                                       # Используем контекстный менеджер "with" для создания объекта mp_pose.Pose
                      min_detection_confidence=0.5,                             # и задаем параметры для pose
                      min_tracking_confidence=0.5
                      ) as pose:

        cap = cv2.VideoCapture(video_file)                                      # Создаем объект cv2.VideoCapture для чтения видео файла
        frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))                    # Получаем количество кадров в видео файле

        with open('dataset.csv', 'a', newline='') as f:
            writer = csv.writer(f)
            n = 0

            for i in tqdm(range(frame_count)):                                  # Пробегаем по каждому кадру в видео файле
                ret, image = cap.read()
                if not ret:                                                     # Если кадр не считался, то прекращаем цикл
                    break
                if flip:
                  image=cv2.flip(image,1)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)                  # Переводим картинку в RGB
                results = pose.process(image)                                   # Обрабатываем изображение для обнаружения скелетных точек
                if results.pose_landmarks is not None :                          # Если скелетные точки обнаружены
                    row = [folder[0], folder[1], folder[2], filename_no_ext, n]    # Создаем новую строку "row" в CSV файле, содержащую имена папок, имя файла и координаты всех 33 скелетных точек
                    #row = ['', '', '', filename_no_ext]
                    for landmark in results.pose_landmarks.landmark:
                        row.append(landmark.x)
                        row.append(landmark.y)
                        row.append(landmark.z)
                        row.append(landmark.visibility)
                    for landmark in results.pose_world_landmarks.landmark:
                        row.append(landmark.x)
                        row.append(landmark.y)
                        row.append(landmark.z)
                        row.append(landmark.visibility)
                    writer.writerow(row)
                    n += 1                                       # Записываем строку "row" в CSV файл

        cap.release()                                                           # Освобождаем ресурсы, используемые 'cap'

# %% [markdown]
# 5. Обрабатываем видеофайлы из списка и записываем скелетные точки в файл CSV

# %%
#Первая часть
for video_file in tqdm(video_files):
    process_video(video_file,flip=False)
    process_video(video_file,flip=True)
    shutil.copy('/content/dataset.csv', '/content/drive/MyDrive/internship/karate/dataset/dataset5.csv')
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# ['wrong', 'УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)', 'side', 'Андрей УЧИ УКЕ (кулак развернут не верно 2).mp4']
# ...
#   0%|          | 0/485 [00:00<?, ?it/s]
# ['wrong', 'УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)', 'side', 'Андрей УЧИ УКЕ (кулак развернут не верно 2).mp4']
#   0%|          | 0/485 [00:00<?, ?it/s]
# ['wrong', 'УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)', 'side', 'Максим УЧИ УКЕ (замах от плеча 2).mp4']
#   0%|          | 0/541 [00:00<?, ?it/s]
# ['wrong', 'УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)', 'side', 'Максим УЧИ УКЕ (замах от плеча 2).mp4']
#   0%|          | 0/541 [00:00<?, ?it/s]
# ['wrong', 'УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)', 'side', 'Максим УЧИ УКЕ (корпус шомен 2).mp4']
#   0%|          | 0/572 [00:00<?, ?it/s]
# ['wrong', 'УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)', 'side', 'Максим УЧИ УКЕ (корпус шомен 2).mp4']
#   0%|          | 0/572 [00:00<?, ?it/s]
# ['wrong', 'УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)', 'side', 'Максим УЧИ УКЕ (кулак развернут не верно 2).mp4']
# ...

# %%
#shutil.copy('/content/dataset.csv', '/content/drive/MyDrive/internship/karate/dataset/dataset1.csv')
# Out:
# '/content/drive/MyDrive/karate/dataset_test_2308.csv'

# %%
df=pd.read_csv('/content/drive/MyDrive/internship/karate/dataset/dataset4.csv')

# %%
df[df['filename']=='Максим УЧИ УКЕ (кулак развернут не верно 2)']
# Out:
# Empty DataFrame
# Columns: [correct, main_folder, folder, filename, frame#, x_0, y_0, z_0, v_0, x_1, y_1, z_1, v_1, x_2, y_2, z_2, v_2, x_3, y_3, z_3, v_3, x_4, y_4, z_4, v_4, x_5, y_5, z_5, v_5, x_6, y_6, z_6, v_6, x_7, y_7, z_7, v_7, x_8, y_8, z_8, v_8, x_9, y_9, z_9, v_9, x_10, y_10, z_10, v_10, x_11, y_11, z_11, v_11, x_12, y_12, z_12, v_12, x_13, y_13, z_13, v_13, x_14, y_14, z_14, v_14, x_15, y_15, z_15, v_15, x_16, y_16, z_16, v_16, x_17, y_17, z_17, v_17, x_18, y_18, z_18, v_18, x_19, y_19, z_19, v_19, x_20, y_20, z_20, v_20, x_21, y_21, z_21, v_21, x_22, y_22, z_22, v_22, x_23, y_23, z_23, ...]
# Index: []
#
# [0 rows x 269 columns]

# %%
len(np.unique(df['filename']))
# Out:
# 112

# %%
df
# Out:
#       correct                                   main_folder folder  \
# 0       wrong  УРАКЕН УЧИ (КРУГОВОЙ УДАР ПЕРЕДНЕЙ РУКОЙ)   side
# 1       wrong  УРАКЕН УЧИ (КРУГОВОЙ УДАР ПЕРЕДНЕЙ РУКОЙ)   side
# 2       wrong  УРАКЕН УЧИ (КРУГОВОЙ УДАР ПЕРЕДНЕЙ РУКОЙ)   side
# 3       wrong  УРАКЕН УЧИ (КРУГОВОЙ УДАР ПЕРЕДНЕЙ РУКОЙ)   side
# 4       wrong  УРАКЕН УЧИ (КРУГОВОЙ УДАР ПЕРЕДНЕЙ РУКОЙ)   side
# ...       ...                                           ...    ...
# 71092   wrong               УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)   side
# 71093   wrong               УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)   side
# 71094   wrong               УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)   side
# 71095   wrong               УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)   side
# 71096   wrong               УЧИ УКЕ (БЛОК ПЕРЕДНЕЙ РУКОЙ)   side
#
#                                     filename  frame#       x_0       y_0  \
# 0          Андрей УРАКЕН УЧИ (нет замаха 2)       0  0.458401  0.195673
# ...

# %% [markdown]
# #Объединяем результаты 2х этапов

# %%
import pandas as pd

df1=pd.read_csv('/content/drive/MyDrive/internship/karate/dataset/dataset_part1.csv')
df2=pd.read_csv('/content/drive/MyDrive/internship/karate/dataset/dataset_part2.csv')
df3=pd.read_csv('/content/drive/MyDrive/internship/karate/dataset/dataset_part3.csv')
df4=pd.read_csv('/content/drive/MyDrive/internship/karate/dataset/dataset_part4.csv')
df5=pd.read_csv('/content/drive/MyDrive/internship/karate/dataset/dataset_part5.csv')

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
print(df4.shape)
print(df5.shape)
# Out:
# (66997, 269)
# (71819, 269)
# (70456, 269)
# (71097, 269)
# (4272, 269)

# %%
df_all=pd.concat([df1,df2,df3,df4,df5])
print(df_all.shape)
# Out:
# (284641, 269)

# %%
df_all.to_csv('/content/drive/MyDrive/internship/karate/dataset/dataset_all.csv',index=False)
